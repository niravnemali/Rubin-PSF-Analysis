# %% [markdown]
# # chatGPT code examples

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# CONFIGURATION
# -------------
import sys
import numpy as np
sys.path.insert(0,'../src/')
np.random.seed(42)

# %%
from example import *

# %%
########################################################
# Run example
########################################################

np.random.seed(42)

image = make_gaussian_image()

# choose beta ~ sigma
beta = 2.0
nmax = 6

coeffs, modes, model = fit_shapelets(image, beta=beta, nmax=nmax)

G = gaussianity_metric(coeffs, modes)
print("Gaussianity metric:", G)

# plot_diagnostics(image, model)
models = compare_models(image)
# Out:
# Gaussianity metric: 0.8848452617025169
#
# === Model comparison ===
# Gaussian χ²:  1430.679
# Moffat  χ²:  1374.243
# Shapelet χ²: 20352.502

# %%
models
# Out:
# {'gaussian': array([1124.40201393,   12.30960082,   11.7023125 ,    2.09905572,
#           15.13981723]),
#  'moffat': array([1183.90034658,   12.31452477,   11.70249165,    5.95408309,
#            4.87685902,   10.57343251]),
#  'shapelet_coeffs': array([ 1221.28389462,   951.87561849,  1379.53915898, -1456.9316775 ,
#         -1064.63962186,   728.18560849,  1049.1018365 , -4203.12159254,
#           231.00948016,    53.34177716,  -296.9332125 ,  -456.93530028,
#           218.95116761,  -545.95317035,   -71.33190518,   457.07073492,
#           123.60001845,   326.97971885,  6153.38163951,  -205.69253167,
#          -671.26256808,   161.50585672,   295.46359187,    21.62641102,
#           407.51496649, -5722.44933516,   130.37889784,  2855.78535363])}
